# %%
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.font_manager as fm

import seaborn as sns

# %%
font_path = '../extra/Cinzel-VariableFont_wght.ttf'

cinzel_font = fm.FontProperties(fname=font_path)
fm.fontManager.addfont(font_path)

# %%
# paths
FONT_PATH     = '../extra/Cinzel-VariableFont_wght.ttf'
DATASETS_PATH = '../data'
IMAGES_PATH   = '../images'
# colors
RED        = '#6F1D1B'
RICH_BLACK = '#011627'
# font size
SIZE_TICKS = 12

# %%
def decorate_plot(ax, xname, yname, loc):
    SIZE_TICKS = 12

    # Eliminate upper and right axes
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # Show ticks in the left and lower axes only
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    # x axis name
    ax.set_xlabel(xname, fontsize=15)

    # y axis name
    ax.set_ylabel(yname, fontsize=15)

    # Adjust the font size of the tick labels
    ax.tick_params(axis='both', which='major', labelsize=SIZE_TICKS)

    if loc:
        plt.legend(fontsize=10, loc=loc)

    # Update font settings
    plt.rcParams.update({
        "font.family": cinzel_font.get_name(), 
        "font.size": 16
    })

    # Adjust layout
    plt.tight_layout()

# %% [markdown]
# <h2> <center> Global Electricity Production </center> </h2>

# %%
electricity_df = pd.read_csv('../data/global_electricity_production_data.csv')
electricity_df
# Out:
#          country_name       date                       parameter  \
# 0           Australia  12/1/2023      Net Electricity Production
# 1           Australia  12/1/2023      Net Electricity Production
# 2           Australia  12/1/2023      Net Electricity Production
# 3           Australia  12/1/2023      Net Electricity Production
# 4           Australia  12/1/2023      Net Electricity Production
# ...               ...        ...                             ...
# 121069  United States   1/1/2010                   Total Imports
# 121070  United States   1/1/2010                   Total Exports
# 121071  United States   1/1/2010         Used for pumped storage
# 121072  United States   1/1/2010             Distribution Losses
# 121073  United States   1/1/2010  Final Consumption (Calculated)
#
#                                   product        value unit
# 0                             Electricity   22646.1901  GWh
# 1                 Total Combustible Fuels   13397.9356  GWh
# 2       Coal, Peat and Manufactured Gases    9768.5223  GWh
# 3              Oil and Petroleum Products     289.5415  GWh
# 4                             Natural Gas    3091.9272  GWh
# ...                                   ...          ...  ...
# 121069                        Electricity    5808.5770  GWh
# 121070                        Electricity     996.5670  GWh
# 121071                        Electricity    2283.3220  GWh
# 121072                        Electricity   22933.2970  GWh
# 121073                        Electricity  343866.4180  GWh
#
# [121074 rows x 6 columns]

# %%
electricity_df['parameter'].value_counts()
# Out:
# parameter
# Net Electricity Production        93318
# Final Consumption (Calculated)     6036
# Distribution Losses                6033
# Total Exports                      5416
# Total Imports                      5411
# Used for pumped storage            4846
# Remarks                              14
# Name: count, dtype: int64

# %%
France_df = electricity_df[(electricity_df['country_name'] == 'France') & 
                           (electricity_df['product'] == 'Electricity') & 
                           (electricity_df['parameter'] == 'Final Consumption (Calculated)')].copy()

# start_date = pd.to_datetime('01/01/2010', format='%m/%d/%Y')
# end_date   = pd.to_datetime('12/01/2023', format='%m/%d/%Y')

France_df['date'] = pd.to_datetime(electricity_df['date'], format='%m/%d/%Y')

# France_df = France_df[(France_df['date'] >= start_date) & 
#                       (France_df['date'] <= end_date)]

France_df.sort_values('date', inplace=True)

France_df
# Out:
#        country_name       date                       parameter      product  \
# 120646       France 2010-01-01  Final Consumption (Calculated)  Electricity
# 120055       France 2010-02-01  Final Consumption (Calculated)  Electricity
# 119465       France 2010-03-01  Final Consumption (Calculated)  Electricity
# 118874       France 2010-04-01  Final Consumption (Calculated)  Electricity
# 118283       France 2010-05-01  Final Consumption (Calculated)  Electricity
# ...             ...        ...                             ...          ...
# 3042         France 2023-08-01  Final Consumption (Calculated)  Electricity
# 2328         France 2023-09-01  Final Consumption (Calculated)  Electricity
# 1612         France 2023-10-01  Final Consumption (Calculated)  Electricity
# 899          France 2023-11-01  Final Consumption (Calculated)  Electricity
# 189          France 2023-12-01  Final Consumption (Calculated)  Electricity
#
#              value unit
# 120646  51864.4470  GWh
# 120055  44840.0980  GWh
# 119465  44523.3080  GWh
# 118874  35470.4870  GWh
# 118283  34182.2760  GWh
# ...            ...  ...
# 3042    29208.8201  GWh
# 2328    29733.9638  GWh
# 1612    31370.2874  GWh
# 899     36889.4457  GWh
# 189     41104.8869  GWh
#
# [168 rows x 6 columns]

# %%
# data = France_df['unit'].value_counts()
# data

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(France_df['date'], France_df['value'], linestyle='-', color=RED)

ax.set_title('France Electricity Consumption')

decorate_plot(ax, 'Month', 'Value (GWh)', '')

# Format the x-axis to show all month names.
# start_year = France_df['date'].dt.year.min()
# end_year = France_df['date'].dt.year.max()

# months = pd.date_range("2020-01-01", "2023-12-01", freq='MS')
# ax.set_xticks(months)
# ax.set_xticklabels(months.strftime('%b'))

year_locator = mdates.YearLocator()
year_formatter = mdates.DateFormatter('%Y')
ax.xaxis.set_major_locator(year_locator)
ax.xaxis.set_major_formatter(year_formatter)

# plt.xticks(rotation=0)

# plt.savefig(f'images/time_series_example_France.png', dpi=300, transparent=True)

plt.show()

# %%
France_df = France_df[['date', 'value']]
# France_df['date'] = pd.to_datetime(France_df['date'])
France_df.set_index('date', inplace=True)
# France_df

# %% [markdown]
# <h2> <center> Video Game Sales </center> </h2>

# %%
games_df = pd.read_csv('../data/vgsales.csv')
games_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
# games_df = games_df[(games_df['Platform'] == 'PC') & (games_df['Name'] == 'Need for Speed: Most Wanted')].copy()
# games_df = games_df[(games_df['Platform'] == 'PC')].copy()

games_df = games_df.groupby('Year')['Global_Sales'].sum().reset_index()

games_df.dropna(subset=['Year'], inplace=True)
games_df.sort_values('Year', inplace=True)

# games_df

# %%
# games_df['Name'].value_counts()

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(games_df['Year'], games_df['Global_Sales'], linestyle='-', color=RED)

ax.set_title('Global Video Game Sales')

decorate_plot(ax, 'Year', 'Worldwide sales (in millions)', '')

# plt.savefig(f'images/time_series_example_France.png', dpi=300, transparent=True)

plt.show()

# %% [markdown]
# <h2> <center> Avocado Sales </center> </h2>

# %%
avocado_df = pd.read_csv('../data/avocado.csv')
avocado_df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
# avocado_df = avocado_df.groupby('Date')['AveragePrice'].mean().reset_index()
avocado_df = avocado_df.groupby('Date')['Total Volume'].mean().reset_index()

avocado_df['Date'] = pd.to_datetime(avocado_df['Date'], format='%Y-%m-%d')

avocado_df.sort_values('Date', inplace=True)

# avocado_df['region'].value_counts()

avocado_df
# Out:
#           Date  Total Volume
# 0   2015-01-04  7.840216e+05
# 1   2015-01-11  7.273686e+05
# 2   2015-01-18  7.258221e+05
# 3   2015-01-25  7.080211e+05
# 4   2015-02-01  1.106048e+06
# ..         ...           ...
# 164 2018-02-25  1.011402e+06
# 165 2018-03-04  1.035601e+06
# 166 2018-03-11  1.032085e+06
# 167 2018-03-18  1.052537e+06
# 168 2018-03-25  1.095083e+06
#
# [169 rows x 2 columns]

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(avocado_df['Date'], avocado_df['Total Volume'], linestyle='-', color=RED)

ax.set_title('Avocado Sales')

decorate_plot(ax, 'Year', 'Total Number Of Avocados Sold', '')

# plt.savefig(f'../images/time_series_example_avocado.png', dpi=300, transparent=True)

plt.show()

# %% [markdown]
# <h2> <center> Gold Price </center> </h2>

# %%
gold_df = pd.read_csv('../data/gold_prices_quarterly.csv')
gold_df
# Out:
#            Date      USD      EUR        JPY      GBP      CAD      CHF  \
# 0    12/29/1978    214.1    132.1        NaN    107.8      NaN      NaN
# 1     3/30/1979    238.1    146.6   47,981.2    118.1    282.0    398.5
# 2     6/29/1979    259.3    161.3   56,555.9    124.5    300.6    444.5
# 3     9/28/1979    315.7    190.2   69,090.6    141.6    368.0    517.0
# 4    12/31/1979    408.4    243.8   98,086.0    189.5    483.4    668.8
# ..          ...      ...      ...        ...      ...      ...      ...
# 174   6/30/2022  1,870.6  1,758.1  242,875.3  1,491.3  2,389.4  1,806.3
# 175   9/30/2022  1,728.9  1,717.2  238,933.9  1,469.6  2,257.1  1,671.2
# 176  12/30/2022  1,725.9  1,693.6  244,438.3  1,471.6  2,342.5  1,664.8
# 177   3/31/2023  1,889.9  1,761.0  250,143.8  1,554.6  2,555.8  1,748.6
# 178   6/30/2023  1,975.9  1,815.1  271,813.9  1,577.6  2,652.3  1,775.6
#
#            INR       CNY       TRY      SAR           IDR      AED       THB  \
# 0          NaN       NaN       NaN      NaN           NaN      NaN       NaN
# 1      1,944.0       NaN       NaN    794.7     148,515.9    910.7   4,800.9
# 2      2,114.6       NaN       NaN    878.4     161,455.6    991.7   5,226.6
# 3      2,517.7       NaN       NaN  1,061.0     197,436.4  1,195.6   6,420.3
# 4      3,347.6       NaN       NaN  1,384.4     257,354.3  1,555.9   8,345.5
# ..         ...       ...       ...      ...           ...      ...       ...
# 174  144,445.6  12,373.6  29,516.9  7,017.2  27,256,748.6  6,870.7  64,372.4
# 175  137,916.6  11,836.3  30,994.5  6,495.7  25,814,666.9  6,350.3  62,921.4
# 176  141,718.8  12,285.1  32,124.8  6,487.5  26,846,159.6  6,338.9  62,796.6
# 177  155,342.7  12,929.6  35,693.9  7,095.3  28,763,364.6  6,941.4  64,113.6
# 178  162,334.1  13,875.5  41,668.7  7,411.1  29,411,415.3  7,256.6  68,113.8
#
#               VND       EGP          KRW        RUB       ZAR      AUD
# 0             NaN       NaN          NaN        NaN       NaN      NaN
# 1             NaN       NaN    115,233.4        NaN     203.5    210.2
# 2             NaN       NaN    124,572.2        NaN     219.2    233.9
# 3             NaN       NaN    153,057.5        NaN     264.1    279.9
# 4             NaN       NaN    199,028.3        NaN     340.6    372.8
# ..            ...       ...          ...        ...       ...      ...
# 174  43,164,258.4  34,671.0  2,361,500.2  125,560.1  29,210.8  2,623.1
# 175  40,566,422.8  33,100.8  2,317,227.7  104,327.3  29,442.6  2,531.4
# 176  42,014,855.4  39,864.7  2,350,658.0  108,431.2  30,429.0  2,629.2
# 177  44,531,622.8  56,929.3  2,412,139.9  138,770.6  33,585.3  2,765.8
# 178  46,404,748.2  61,064.8  2,599,169.7  161,129.0  36,920.2  2,956.5
#
# [179 rows x 20 columns]

# %%
gold_df['USD'] = gold_df['USD'].str.replace(',', '').astype(float)

gold_df['Date'] = pd.to_datetime(gold_df['Date'], format='%m/%d/%Y')

gold_df.sort_values('Date', inplace=True)

gold_df
# Out:
#           Date     USD      EUR        JPY      GBP      CAD      CHF  \
# 0   1978-12-29   214.1    132.1        NaN    107.8      NaN      NaN
# 1   1979-03-30   238.1    146.6   47,981.2    118.1    282.0    398.5
# 2   1979-06-29   259.3    161.3   56,555.9    124.5    300.6    444.5
# 3   1979-09-28   315.7    190.2   69,090.6    141.6    368.0    517.0
# 4   1979-12-31   408.4    243.8   98,086.0    189.5    483.4    668.8
# ..         ...     ...      ...        ...      ...      ...      ...
# 174 2022-06-30  1870.6  1,758.1  242,875.3  1,491.3  2,389.4  1,806.3
# 175 2022-09-30  1728.9  1,717.2  238,933.9  1,469.6  2,257.1  1,671.2
# 176 2022-12-30  1725.9  1,693.6  244,438.3  1,471.6  2,342.5  1,664.8
# 177 2023-03-31  1889.9  1,761.0  250,143.8  1,554.6  2,555.8  1,748.6
# 178 2023-06-30  1975.9  1,815.1  271,813.9  1,577.6  2,652.3  1,775.6
#
#            INR       CNY       TRY      SAR           IDR      AED       THB  \
# 0          NaN       NaN       NaN      NaN           NaN      NaN       NaN
# 1      1,944.0       NaN       NaN    794.7     148,515.9    910.7   4,800.9
# 2      2,114.6       NaN       NaN    878.4     161,455.6    991.7   5,226.6
# 3      2,517.7       NaN       NaN  1,061.0     197,436.4  1,195.6   6,420.3
# 4      3,347.6       NaN       NaN  1,384.4     257,354.3  1,555.9   8,345.5
# ..         ...       ...       ...      ...           ...      ...       ...
# 174  144,445.6  12,373.6  29,516.9  7,017.2  27,256,748.6  6,870.7  64,372.4
# 175  137,916.6  11,836.3  30,994.5  6,495.7  25,814,666.9  6,350.3  62,921.4
# 176  141,718.8  12,285.1  32,124.8  6,487.5  26,846,159.6  6,338.9  62,796.6
# 177  155,342.7  12,929.6  35,693.9  7,095.3  28,763,364.6  6,941.4  64,113.6
# 178  162,334.1  13,875.5  41,668.7  7,411.1  29,411,415.3  7,256.6  68,113.8
#
#               VND       EGP          KRW        RUB       ZAR      AUD
# 0             NaN       NaN          NaN        NaN       NaN      NaN
# 1             NaN       NaN    115,233.4        NaN     203.5    210.2
# 2             NaN       NaN    124,572.2        NaN     219.2    233.9
# 3             NaN       NaN    153,057.5        NaN     264.1    279.9
# 4             NaN       NaN    199,028.3        NaN     340.6    372.8
# ..            ...       ...          ...        ...       ...      ...
# 174  43,164,258.4  34,671.0  2,361,500.2  125,560.1  29,210.8  2,623.1
# 175  40,566,422.8  33,100.8  2,317,227.7  104,327.3  29,442.6  2,531.4
# 176  42,014,855.4  39,864.7  2,350,658.0  108,431.2  30,429.0  2,629.2
# 177  44,531,622.8  56,929.3  2,412,139.9  138,770.6  33,585.3  2,765.8
# 178  46,404,748.2  61,064.8  2,599,169.7  161,129.0  36,920.2  2,956.5
#
# [179 rows x 20 columns]

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(gold_df['Date'], gold_df['USD'], linestyle='-', color=RED)

ax.set_title('Gold Price')

decorate_plot(ax, 'Year', 'Gold Price (USD)', '')

# plt.savefig(f'images/time_series_example_France.png', dpi=300, transparent=True)

plt.show()

# %% [markdown]
# <h2> <center> Groceries </center> </h2>

# %%
groceries_df = pd.read_csv('../data/Groceries_dataset.csv')
groceries_df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
groceries_df.value_counts()
# Out:
# Member_number  Date        itemDescription
# 1994           11-03-2015  whole milk             4
# 2430           28-01-2014  pastry                 3
# 1245           27-06-2015  soda                   3
# 1225           26-02-2015  whole milk             3
# 2779           17-10-2015  whole milk             3
#                                                  ..
# 5000           10-02-2015  root vegetables        1
#                            semi-finished bread    1
#                            soda                   1
#                16-11-2014  bottled beer           1
# 1000           24-06-2014  salty snack            1
# Name: count, Length: 38006, dtype: int64

# %% [markdown]
# <h2> <center> Wine Australia </center> </h2>

# %%
wine_df = pd.read_csv('../data/AusWineSales.csv')
wine_df
# Out:
#     YearMonth   Red  Sparkling  Sweetwhite
# 0     1980-01   464       1686          85
# 1     1980-02   675       1591          89
# 2     1980-03   703       2304         109
# 3     1980-04   887       1712          95
# 4     1980-05  1139       1471          91
# ..        ...   ...        ...         ...
# 182   1995-03  2459       1897         188
# 183   1995-04  2618       1862         195
# 184   1995-05  2585       1670         189
# 185   1995-06  3310       1688         220
# 186   1995-07  3923       2031         274
#
# [187 rows x 4 columns]

# %%
wine_df = wine_df[['YearMonth', 'Red']].copy()
wine_df['YearMonth'] = pd.to_datetime(wine_df['YearMonth'], format='%Y-%m')

wine_df.sort_values('YearMonth', inplace=True)
wine_df
# Out:
#      YearMonth   Red
# 0   1980-01-01   464
# 1   1980-02-01   675
# 2   1980-03-01   703
# 3   1980-04-01   887
# 4   1980-05-01  1139
# ..         ...   ...
# 182 1995-03-01  2459
# 183 1995-04-01  2618
# 184 1995-05-01  2585
# 185 1995-06-01  3310
# 186 1995-07-01  3923
#
# [187 rows x 2 columns]

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(wine_df['YearMonth'], wine_df['Red'], linestyle='-', color=RED)

ax.set_title('Australian Wine Sales')

decorate_plot(ax, 'Year', 'Wine Sales (Volume)', '')

# plt.savefig(f'../images/time_series_example_wine.png', dpi=300, transparent=True)

plt.show()

# %% [markdown]
# <h2> <center> Hourly Energy Consumption </center> </h2>

# %%
df = pd.read_csv("../data/AEP_hourly.csv", parse_dates=["Datetime"])
df.set_index("Datetime", inplace=True)

df.loc[f'2004']

# plt.figure(figsize=(12, 6))
# plt.plot(df.index, df["AEP_MW"])

# # Format x-axis to show hours/minutes
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
# plt.gca().xaxis.set_major_locator(mdates.HourLocator(interval=1))  # Show every hour

# plt.xlabel("Time (HH:MM)")
# plt.ylabel("AEP_MW")
# plt.title("Time Series Plot")
# plt.xticks(rotation=45)  # Rotate labels for readability
# plt.grid(True)
# plt.tight_layout()
# plt.show()
# Out:
#                       AEP_MW
# Datetime
# 2004-12-31 01:00:00  13478.0
# 2004-12-31 02:00:00  12865.0
# 2004-12-31 03:00:00  12577.0
# 2004-12-31 04:00:00  12517.0
# 2004-12-31 05:00:00  12670.0
# ...                      ...
# 2004-10-01 20:00:00  15211.0
# 2004-10-01 21:00:00  15349.0
# 2004-10-01 22:00:00  14837.0
# 2004-10-01 23:00:00  14067.0
# 2004-10-02 00:00:00  13147.0
#
# [2206 rows x 1 columns]

# %%
# helper function to decorate plots
def decorate_regular_plot(ax, xname: str, 
                              yname: str, 
                              loc=None) -> None:
    SIZE_TICKS = 12

    # eliminate upper and right axes
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # show ticks in the left and lower axes only
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    # x axis name
    ax.set_xlabel(xname, fontsize=15)

    # y axis name
    ax.set_ylabel(yname, fontsize=15)

    # adjust the font size of the tick labels
    ax.tick_params(axis='both', which='major', labelsize=SIZE_TICKS)

    if loc:
        plt.legend(fontsize=10, loc=loc)

    # adjust layout
    plt.tight_layout()

# %%
# regular time series plot style
classic_style = {
    "font.family": cinzel_font.get_name(), # apply Cinzel font
    "font.size": 16
}

# lag plot style
lag_plot_style = {
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "axes.grid": True,
    "grid.color": "#8D99AE",
}

# acf plot style
acf_plot_style = {
    "font.family": cinzel_font.get_name(), # apply Cinzel font
    "font.size": 24
}

# %% [markdown]
# ### American Electric Power

# %%
# load data
aep_df = pd.read_csv(
    f'{DATASETS_PATH}/AEP_hourly.csv',
    parse_dates=['Datetime'],
    dayfirst=False
).set_index('Datetime').sort_index()

# process data
aep_df = aep_df.loc[f'2009']

# create plot
with plt.rc_context(classic_style): # use context for styles not to interfere
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.plot(aep_df.index, aep_df['AEP_MW'], color=RED, linewidth=1.5)

    ax.set_title('Hourly American Electric Power Consumption')
    decorate_regular_plot(ax, 'Year-Month', 'AEP Consumption (MW)')

    # plt.savefig(f'{IMAGES_PATH}/time_series_example_aep.png', dpi=300, transparent=True)

    plt.show()

# %% [markdown]
# ### Groceries

# %%
# load data
df = pd.read_csv(
    f'{DATASETS_PATH}/Groceries_dataset.csv',
    parse_dates=['Date'],
    dayfirst=True
).set_index('Date').sort_index()

# process data
start_month = df.index.min().to_period('M').to_timestamp()
end_month   = df.index.max().to_period('M').to_timestamp('M')

whole_milk = df[df['itemDescription'] == 'whole milk']

time_series = whole_milk.resample('ME').size() 
full_date_range = pd.date_range(start=start_month, end=end_month, freq='ME')
time_series_full = time_series.reindex(full_date_range, fill_value=0)

# create plot
with plt.rc_context(classic_style): # use context for styles not to interfere
    fig, ax = plt.subplots(figsize=(7, 6))

    time_series_full.plot(kind='line', linewidth=1.5, color=RED)

    ax.set_title('Monthly Milk Purchases')
    decorate_regular_plot(ax, 'Month', 'Milk Purchases')

    # plt.savefig(f'{IMAGES_PATH}/time_series_example_milk.png', dpi=300, transparent=True)

    plt.show()

# %% [markdown]
# ### Dow Jones Index

# %%
# load data
dowJones_df = pd.read_csv(
    f'{DATASETS_PATH}/dow_jones_index.data',
    parse_dates=['date'],
    dayfirst=False
)

# process data
dowJones_df['close'] = dowJones_df['close'].str.replace('$', '').astype(float)

dowJones_df = dowJones_df[
    (dowJones_df['stock'] == 'AA')
].copy().set_index('date').sort_index()

# average_close = dowJones_df.groupby('date')['close'].mean().reset_index(name='average_close')
# average_close = average_close.set_index('date').sort_index()

print(dowJones_df)

# create plot
with plt.rc_context(classic_style): # use context for styles not to interfere
    fig, ax = plt.subplots(figsize=(7, 6))
    ax.plot(dowJones_df.index, dowJones_df['close'], color=RED, linewidth=1.5)

    ax.set_title('Closing Dow Jones Index Prices')
    decorate_regular_plot(ax, 'Date', '$')

    # plt.savefig(f'{IMAGES_PATH}/time_series_example_aep.png', dpi=300, transparent=True)

    plt.show()
# Out:
#             quarter stock    open    high     low  close     volume  \
# date
# 2011-01-07        1    AA  $15.82  $16.72  $15.78  16.42  239655616
# 2011-01-14        1    AA  $16.71  $16.71  $15.64  15.97  242963398
# 2011-01-21        1    AA  $16.19  $16.38  $15.60  15.79  138428495
# 2011-01-28        1    AA  $15.87  $16.63  $15.82  16.13  151379173
# 2011-02-04        1    AA  $16.18  $17.39  $16.18  17.14  154387761
# 2011-02-11        1    AA  $17.33  $17.48  $16.97  17.37  114691279
# 2011-02-18        1    AA  $17.39  $17.68  $17.28  17.28   80023895
# 2011-02-25        1    AA  $16.98  $17.15  $15.96  16.68  132981863
# 2011-03-04        1    AA  $16.81  $16.94  $16.13  16.58  109493077
# 2011-03-11        1    AA  $16.58  $16.75  $15.42  16.03  114332562
# 2011-03-18        1    AA  $15.95  $16.33  $15.43  16.11  130374108
# 2011-03-25        1    AA  $16.38  $17.24  $16.26  17.09   95550392
# 2011-04-01        2    AA  $17.13  $17.80  $17.02  17.47  103320396
# 2011-04-08        2    AA  $17.42  $18.47  $17.42  17.92  129237024
# 2011-04-15        2    AA  $18.06  $18.19  $16.38  16.52  213061090
# 2011-04-21        2    AA  $16.36  $16.97  $15.88  16.97   85235391
# 2011-04-29        2    AA  $16.94  $17.24  $16.66  17.00   90831895
# 2011-05-06        2    AA  $17.27  $17.96  $16.83  17.15  225053559
# 2011-05-13        2    AA  $17.16  $17.62  $16.75  17.10  111630753
# 2011-05-20        2    AA  $17.00  $17.29  $16.26  16.26  118281015
# 2011-05-27        2    AA  $15.96  $16.48  $15.83  16.48   77236662
# 2011-06-03        2    AA  $16.73  $16.83  $15.77  15.92   77152591
# 2011-06-10        2    AA  $15.92  $16.03  $15.17  15.28   94970970
# 2011-06-17        2    AA  $15.29  $15.50  $14.59  14.72  111273573
# 2011-06-24        2    AA  $14.67  $15.60  $14.56  15.23   99423717
#
#             percent_change_price  percent_change_volume_over_last_wk  \
# date
# 2011-01-07              3.792670                                 NaN
# 2011-01-14             -4.428490                            1.380223
# 2011-01-21             -2.470660                          -43.024959
# 2011-01-28              1.638310                            9.355500
# 2011-02-04              5.933250                            1.987452
# 2011-02-11              0.230814                          -25.712195
# 2011-02-18             -0.632547                          -30.226696
# 2011-02-25             -1.766780                           66.177694
# 2011-03-04             -1.368230                          -17.663150
# 2011-03-11             -3.317250                            4.419900
# 2011-03-18              1.003130                           14.030601
# 2011-03-25              4.334550                          -26.710607
# 2011-04-01              1.984820                            8.131839
# 2011-04-08              2.870260                           25.083748
# 2011-04-15             -8.527130                           64.860721
# 2011-04-21              3.728610                          -59.994858
# 2011-04-29              0.354191                            6.565939
# 2011-05-06             -0.694847                          147.769309
# 2011-05-13             -0.349650                          -50.398139
# 2011-05-20             -4.352940                            5.957374
# 2011-05-27              3.258150                          -34.700711
# 2011-06-03             -4.841600                           -0.108849
# 2011-06-10             -4.020100                           23.094985
# 2011-06-17             -3.727930                           17.165880
# 2011-06-24              3.817310                          -10.649299
#
#             previous_weeks_volume next_weeks_open next_weeks_close  \
# date
# 2011-01-07                    NaN          $16.71           $15.97
# 2011-01-14            239655616.0          $16.19           $15.79
# 2011-01-21            242963398.0          $15.87           $16.13
# 2011-01-28            138428495.0          $16.18           $17.14
# 2011-02-04            151379173.0          $17.33           $17.37
# 2011-02-11            154387761.0          $17.39           $17.28
# 2011-02-18            114691279.0          $16.98           $16.68
# 2011-02-25             80023895.0          $16.81           $16.58
# 2011-03-04            132981863.0          $16.58           $16.03
# 2011-03-11            109493077.0          $15.95           $16.11
# 2011-03-18            114332562.0          $16.38           $17.09
# 2011-03-25            130374108.0          $17.13           $17.47
# 2011-04-01             95550392.0          $17.42           $17.92
# 2011-04-08            103320396.0          $18.06           $16.52
# 2011-04-15            129237024.0          $16.36           $16.97
# 2011-04-21            213061090.0          $16.94           $17.00
# 2011-04-29             85235391.0          $17.27           $17.15
# 2011-05-06             90831895.0          $17.16           $17.10
# 2011-05-13            225053559.0          $17.00           $16.26
# 2011-05-20            111630753.0          $15.96           $16.48
# 2011-05-27            118281015.0          $16.73           $15.92
# 2011-06-03             77236662.0          $15.92           $15.28
# 2011-06-10             77152591.0          $15.29           $14.72
# 2011-06-17             94970970.0          $14.67           $15.23
# 2011-06-24            111273573.0          $15.22           $16.31
#
#             percent_change_next_weeks_price  days_to_next_dividend  \
# date
# 2011-01-07                        -4.428490                     26
# 2011-01-14                        -2.470660                     19
# 2011-01-21                         1.638310                     12
# 2011-01-28                         5.933250                      5
# 2011-02-04                         0.230814                     97
# 2011-02-11                        -0.632547                     90
# 2011-02-18                        -1.766780                     83
# 2011-02-25                        -1.368230                     76
# 2011-03-04                        -3.317250                     69
# 2011-03-11                         1.003130                     62
# 2011-03-18                         4.334550                     55
# 2011-03-25                         1.984820                     48
# 2011-04-01                         2.870260                     41
# 2011-04-08                        -8.527130                     34
# 2011-04-15                         3.728610                     27
# 2011-04-21                         0.354191                     21
# 2011-04-29                        -0.694847                     13
# 2011-05-06                        -0.349650                      6
# 2011-05-13                        -4.352940                     82
# 2011-05-20                         3.258150                     75
# 2011-05-27                        -4.841600                     68
# 2011-06-03                        -4.020100                     61
# 2011-06-10                        -3.727930                     54
# 2011-06-17                         3.817310                     47
# 2011-06-24                         7.161630                     40
#
#             percent_return_next_dividend
# date
# 2011-01-07                      0.182704
# 2011-01-14                      0.187852
# 2011-01-21                      0.189994
# 2011-01-28                      0.185989
# 2011-02-04                      0.175029
# 2011-02-11                      0.172712
# 2011-02-18                      0.173611
# 2011-02-25                      0.179856
# 2011-03-04                      0.180941
# 2011-03-11                      0.187149
# 2011-03-18                      0.186220
# 2011-03-25                      0.175541
# 2011-04-01                      0.171723
# 2011-04-08                      0.167411
# 2011-04-15                      0.181598
# 2011-04-21                      0.176783
# 2011-04-29                      0.176471
# 2011-05-06                      0.174927
# 2011-05-13                      0.175439
# 2011-05-20                      0.184502
# 2011-05-27                      0.182039
# 2011-06-03                      0.188442
# 2011-06-10                      0.196335
# 2011-06-17                      0.203804
# 2011-06-24                      0.196980
